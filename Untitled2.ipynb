# %%
import sqlite3

import matplotlib.pyplot as plt

import numpy as np
import pandas as pd 
import seaborn as sns
# %matplotlib inline

# %%
cnx = sqlite3.connect(r'C:\Users\Nataly\AppData\Roaming\DBeaverData\workspace6\.metadata\sample-database-sqlite-1\Chinook.db')

# %%
df1 = pd.read_sql_query("SELECT * FROM Invoice", cnx, index_col='InvoiceId')

# %%
df1.tail()
# Out:
#            CustomerId          InvoiceDate  \
# InvoiceId
# 408                25  2011-12-05 00:00:00
# 409                29  2011-12-06 00:00:00
# 410                35  2011-12-09 00:00:00
# 411                44  2011-12-14 00:00:00
# 412                58  2011-12-22 00:00:00
#
#                                      BillingAddress BillingCity BillingState  \
# InvoiceId
# 408                           319 N. Frances Street     Madison           WI
# 409                          796 Dundas Street West     Toronto           ON
# 410        Rua dos Campeões Europeus de Viena, 4350       Porto         None
# 411                                 Porthaninkatu 9    Helsinki         None
# 412                             12,Community Centre       Delhi         None
#
#           BillingCountry BillingPostalCode  Total
# InvoiceId
# 408                  USA             53703   3.96
# 409               Canada           M6J 1V1   5.94
# 410             Portugal              None   8.91
# ...

# %%
df2 = pd.read_sql_query("SELECT * FROM Customer", cnx, index_col='CustomerId')

# %%
df2.tail()
# Out:
#            FirstName    LastName Company              Address          City  \
# CustomerId
# 55              Mark      Taylor    None    421 Bourke Street        Sidney
# 56             Diego   Gutiérrez    None   307 Macacha Güemes  Buenos Aires
# 57              Luis       Rojas    None      Calle Lira, 198      Santiago
# 58             Manoj      Pareek    None  12,Community Centre         Delhi
# 59              Puja  Srivastava    None    3,Raj Bhavan Road     Bangalore
#
#            State    Country PostalCode                Phone   Fax  \
# CustomerId
# 55           NSW  Australia       2010   +61 (02) 9332 3633  None
# 56          None  Argentina       1106  +54 (0)11 4311 4333  None
# 57          None      Chile       None    +56 (0)2 635 4444  None
# 58          None      India     110017    +91 0124 39883988  None
# 59          None      India     560001     +91 080 22289999  None
#
#                                Email  SupportRepId
# CustomerId
# ...

# %%
sns.violinplot(x='Total', data=df1)

# %%
df1['Total'].hist()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 1 to 412
# Data columns (total 8 columns):
# CustomerId           412 non-null int64
# InvoiceDate          412 non-null object
# BillingAddress       412 non-null object
# BillingCity          412 non-null object
# BillingState         210 non-null object
# BillingCountry       412 non-null object
# BillingPostalCode    384 non-null object
# Total                412 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 29.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 1 to 59
# Data columns (total 12 columns):
# FirstName       59 non-null object
# LastName        59 non-null object
# Company         10 non-null object
# Address         59 non-null object
# City            59 non-null object
# State           30 non-null object
# Country         59 non-null object
# PostalCode      55 non-null object
# Phone           58 non-null object
# Fax             12 non-null object
# Email           59 non-null object
# SupportRepId    59 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 6.0+ KB

# %%
df2['City'].unique()
# Out:
# array(['São José dos Campos', 'Stuttgart', 'Montréal', 'Oslo', 'Prague',
#        'Vienne', 'Brussels', 'Copenhagen', 'São Paulo', 'Rio de Janeiro',
#        'Brasília', 'Edmonton', 'Vancouver', 'Mountain View', 'Redmond',
#        'New York', 'Cupertino', 'Reno', 'Orlando', 'Boston', 'Chicago',
#        'Madison', 'Fort Worth', 'Tucson', 'Salt Lake City', 'Toronto',
#        'Ottawa', 'Halifax', 'Winnipeg', 'Yellowknife', 'Lisbon', 'Porto',
#        'Berlin', 'Frankfurt', 'Paris', 'Lyon', 'Bordeaux', 'Dijon',
#        'Helsinki', 'Budapest', 'Dublin', 'Rome', 'Amsterdam', 'Warsaw',
#        'Madrid', 'Stockholm', 'London', 'Edinburgh ', 'Sidney',
#        'Buenos Aires', 'Santiago', 'Delhi', 'Bangalore'], dtype=object)

# %%
df2['City'].value_counts()
# Out:
# Prague                 2
# Mountain View          2
# Berlin                 2
# São Paulo              2
# London                 2
# Paris                  2
# Stuttgart              1
# Rome                   1
# Sidney                 1
# Warsaw                 1
# Frankfurt              1
# Reno                   1
# New York               1
# Madrid                 1
# Salt Lake City         1
# Toronto                1
# Boston                 1
# Madison                1
# Brasília               1
# Brussels               1
# Montréal               1
# Buenos Aires           1
# Vancouver              1
# Lyon                   1
# Lisbon                 1
# Redmond                1
# Winnipeg               1
# Porto                  1
# Ottawa                 1
# Oslo                   1
# Stockholm              1
# Edmonton               1
# Tucson                 1
# Delhi                  1
# Fort Worth             1
# Cupertino              1
# Amsterdam              1
# ...

# %%
df1['InvoiceDate']= pd.to_datetime(df1['InvoiceDate'])

# %%
country_city_total=df1.groupby(['BillingCountry', 'InvoiceDate'])['Total'].sum()

# %%
country_city_total.head(20)
# Out:
# BillingCountry  InvoiceDate
# Argentina       2008-06-11      1.98
#                 2008-09-13      3.96
#                 2008-12-16      5.94
#                 2009-08-06      0.99
#                 2011-01-28      1.98
#                 2011-03-10     13.86
#                 2011-11-08      8.91
# Australia       2007-04-04      1.98
#                 2007-07-07      3.96
#                 2007-10-09      5.94
#                 2008-05-29      0.99
#                 2009-11-20      1.98
#                 2009-12-31     13.86
#                 2010-08-31      8.91
# Austria         2007-12-08      1.98
#                 2008-01-18     18.86
#                 2008-09-17      8.91
#                 2010-04-24      1.98
#                 2010-07-27      3.96
#                 2010-10-29      5.94
# Name: Total, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.lineplot(df1['InvoiceDate'], df1['Total'], ax=ax)
